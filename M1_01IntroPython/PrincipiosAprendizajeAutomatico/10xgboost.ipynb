# %% [markdown]
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fbigdatamagazine.es%2Fwp-content%2Fuploads%2F2023%2F02%2FFOTO-OK-BDM-DIG-DATA-MAGAZINE.jpg&f=1&nofb=1&ipt=4061921fa0da07483f83edb036d31f25545b2cae889c7eeefebd576f6e0fe5f4" style="width:300px; float: right; margin: 0 40px 40px 40px;"></img>
#
# En este tutorial, aprenderás cómo construir y optimizar modelos con **gradient boosting**. Este método domina muchas competiciones de Kaggle y alcanza resultados de última generación en una variedad de conjuntos de datos.
#
# # Introducción
#
# Durante gran parte de este curso, has hecho predicciones con el método de bosques aleatorios, el cual logra un mejor rendimiento que un solo árbol de decisión simplemente promediando las predicciones de muchos árboles de decisión.
#
# Nos referimos al método del bosque aleatorio como un "método de ensamblado". Por definición, los **métodos de ensamblado** combinan las predicciones de varios modelos (por ejemplo, varios árboles en el caso de los bosques aleatorios).
#
# A continuación, aprenderemos sobre otro método de ensamblado llamado gradient boosting.
#
# # Gradient Boosting
#
# El **gradient boosting** es un método que realiza ciclos para añadir modelos de manera iterativa a un ensamblado.
#
# Comienza inicializando el ensamblado con un solo modelo, cuyas predicciones pueden ser bastante ingenuas. (Incluso si sus predicciones son muy inexactas, las adiciones posteriores al ensamblado corregirán esos errores).
#
# Luego, iniciamos el ciclo:
# - Primero, usamos el ensamblado actual para generar predicciones para cada observación en el conjunto de datos. Para hacer una predicción, sumamos las predicciones de todos los modelos del ensamblado.
# - Estas predicciones se usan para calcular una función de pérdida (como el [error cuadrático medio](https://es.wikipedia.org/wiki/Error_cuadr%C3%A1tico_medio), por ejemplo).
# - Luego, usamos la función de pérdida para ajustar un nuevo modelo que será añadido al ensamblado. Específicamente, determinamos los parámetros del modelo de forma que al añadir este nuevo modelo al ensamblado, se reduzca la pérdida. (*Nota: El "gradiente" en "gradient boosting" se refiere al hecho de que se utiliza [descenso por gradiente](https://es.wikipedia.org/wiki/Descenso_del_gradiente) sobre la función de pérdida para determinar los parámetros de este nuevo modelo.*)
# - Finalmente, añadimos el nuevo modelo al ensamblado, y...
# - ... ¡repetimos!
#
# ![tut6_boosting](https://storage.googleapis.com/kaggle-media/learn/images/MvCGENh.png)
#
# # Ejemplo
#
# Comenzamos cargando los datos de entrenamiento y validación en `X_train`, `X_valid`, `y_train` y `y_valid`.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Leer los datos
data = pd.read_csv('/content/melb_data.csv')

# Seleccionar un subconjunto de predictores
cols_to_use = ['Rooms', 'Distance', 'Landsize', 'BuildingArea', 'YearBuilt']
X = data[cols_to_use]

# Seleccionar la variable objetivo
y = data.Price

# Dividir los datos en conjuntos de entrenamiento y validación
X_train, X_valid, y_train, y_valid = train_test_split(X, y)

# %% [markdown]
# En este ejemplo, trabajarás con la librería XGBoost. **XGBoost** significa **extreme gradient boosting** (refuerzo de gradiente extremo), que es una implementación del gradient boosting con varias características adicionales enfocadas en el rendimiento y la velocidad. (_Scikit-learn tiene otra versión de gradient boosting, pero XGBoost presenta algunas ventajas técnicas._)
#
# En la siguiente celda de código, importamos la API de scikit-learn para XGBoost ([`xgboost.XGBRegressor`](https://xgboost.readthedocs.io/en/latest/python/python_api.html#module-xgboost.sklearn)). Esto nos permite construir y ajustar un modelo tal como lo haríamos con scikit-learn. Como verás en la salida, la clase `XGBRegressor` tiene muchos parámetros ajustables — ¡pronto aprenderás sobre ellos!

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor()
my_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# También hacemos predicciones y evaluamos el modelo

# %%
from sklearn.metrics import mean_absolute_error

# Hacer predicciones con el conjunto de validación
predictions = my_model.predict(X_valid)

# Imprimir el error absoluto medio
print("Error Absoluto Medio: " + str(mean_absolute_error(predictions, y_valid)))
# Out:
# Error Absoluto Medio: 236856.0188351436

# %% [markdown]
# # Ajuste de Parámetros
#
# XGBoost tiene varios parámetros que pueden afectar drásticamente la precisión y la velocidad de entrenamiento. Los primeros parámetros que deberías entender son:
#
# ### `n_estimators`
# `n_estimators` especifica cuántas veces se ejecuta el ciclo de modelado descrito anteriormente. Es igual al número de modelos que incluimos en el ensamblado.
#
# - Un valor demasiado _bajo_ provoca _subajuste_ (_underfitting_), lo que conduce a predicciones inexactas tanto en los datos de entrenamiento como en los de prueba.
# - Un valor demasiado _alto_ provoca _sobreajuste_ (_overfitting_), lo que produce predicciones precisas en los datos de entrenamiento, pero inexactas en los datos de prueba (_que son los que realmente nos importan_).
#
# Los valores típicos oscilan entre 100 y 1000, aunque esto depende mucho del parámetro `learning_rate`, que se explicará a continuación.
#
# Aquí tienes el código para establecer el número de modelos en el ensamblado:

# %%
# Crear el modelo con 500 árboles (estimadores) en el ensamblado
my_model = XGBRegressor(n_estimators=500)

# Entrenar el modelo con los datos de entrenamiento
my_model.fit(X_train, y_train,
             eval_set=[(X_valid, y_valid)],
             verbose=True)
# Out:
# [0]	validation_0-rmse:535046.34013
# [1]	validation_0-rmse:477517.68097
# [2]	validation_0-rmse:445198.04336
# [3]	validation_0-rmse:425102.65133
# [4]	validation_0-rmse:411945.25967
# [5]	validation_0-rmse:405890.44880
# [6]	validation_0-rmse:400547.88224
# [7]	validation_0-rmse:396933.52512
# [8]	validation_0-rmse:393692.87844
# [9]	validation_0-rmse:388803.91233
# [10]	validation_0-rmse:385732.60096
# [11]	validation_0-rmse:382896.58555
# [12]	validation_0-rmse:381749.42647
# [13]	validation_0-rmse:379709.58522
# [14]	validation_0-rmse:377954.21082
# [15]	validation_0-rmse:378016.61907
# [16]	validation_0-rmse:376364.60665
# [17]	validation_0-rmse:375963.44145
# [18]	validation_0-rmse:375674.31763
# [19]	validation_0-rmse:375083.77748
# [20]	validation_0-rmse:374593.30015
# [21]	validation_0-rmse:372390.99883
# [22]	validation_0-rmse:371509.05685
# [23]	validation_0-rmse:370833.68153
# [24]	validation_0-rmse:370593.03721
# [25]	validation_0-rmse:370313.79977
# [26]	validation_0-rmse:370002.49249
# [27]	validation_0-rmse:369494.55681
# [28]	validation_0-rmse:369418.01780
# [29]	validation_0-rmse:369004.33866
# [30]	validation_0-rmse:368491.25037
# [31]	validation_0-rmse:368350.26050
# [32]	validation_0-rmse:367956.85953
# [33]	validation_0-rmse:367896.05569
# [34]	validation_0-rmse:367808.59731
# [35]	validation_0-rmse:367949.53590
# [36]	validation_0-rmse:367999.86007
# [37]	validation_0-rmse:367605.51833
# [38]	validation_0-rmse:366919.92409
# [39]	validation_0-rmse:366660.74506
# [40]	validation_0-rmse:366623.98129
# [41]	validation_0-rmse:366279.01616
# [42]	validation_0-rmse:365592.61417
# [43]	validation_0-rmse:365697.50576
# [44]	validation_0-rmse:365447.71242
# [45]	validation_0-rmse:365286.62790
# [46]	validation_0-rmse:365036.44702
# [47]	validation_0-rmse:364895.00256
# [48]	validation_0-rmse:365174.03309
# [49]	validation_0-rmse:364863.82140
# [50]	validation_0-rmse:363829.14820
# [51]	validation_0-rmse:363559.95025
# [52]	validation_0-rmse:363085.10475
# [53]	validation_0-rmse:363014.77678
# [54]	validation_0-rmse:362778.16784
# [55]	validation_0-rmse:362728.72741
# [56]	validation_0-rmse:362699.17441
# [57]	validation_0-rmse:362253.70596
# [58]	validation_0-rmse:362034.57800
# [59]	validation_0-rmse:362159.72000
# [60]	validation_0-rmse:362254.84990
# [61]	validation_0-rmse:362169.85387
# [62]	validation_0-rmse:362182.81120
# [63]	validation_0-rmse:362034.67179
# [64]	validation_0-rmse:360880.47862
# [65]	validation_0-rmse:360986.32901
# [66]	validation_0-rmse:361592.97376
# [67]	validation_0-rmse:361608.76083
# [68]	validation_0-rmse:361133.96934
# [69]	validation_0-rmse:361462.40637
# [70]	validation_0-rmse:361375.48105
# [71]	validation_0-rmse:361604.89082
# [72]	validation_0-rmse:361947.06292
# [73]	validation_0-rmse:361839.48646
# [74]	validation_0-rmse:362028.37561
# [75]	validation_0-rmse:362179.47432
# [76]	validation_0-rmse:362143.63229
# [77]	validation_0-rmse:361940.93048
# [78]	validation_0-rmse:361994.10199
# [79]	validation_0-rmse:362266.42103
# [80]	validation_0-rmse:362379.00247
# [81]	validation_0-rmse:362420.74460
# [82]	validation_0-rmse:363131.57135
# [83]	validation_0-rmse:363367.86284
# [84]	validation_0-rmse:363360.12764
# [85]	validation_0-rmse:363399.44615
# [86]	validation_0-rmse:363518.71201
# [87]	validation_0-rmse:363458.18484
# [88]	validation_0-rmse:363375.09352
# [89]	validation_0-rmse:363539.03754
# [90]	validation_0-rmse:364025.19732
# [91]	validation_0-rmse:363952.30471
# [92]	validation_0-rmse:364896.89251
# [93]	validation_0-rmse:365048.09230
# [94]	validation_0-rmse:364838.75719
# [95]	validation_0-rmse:364946.10877
# [96]	validation_0-rmse:364764.04986
# [97]	validation_0-rmse:364618.21042
# [98]	validation_0-rmse:364378.01982
# [99]	validation_0-rmse:364688.09217
# [100]	validation_0-rmse:364634.34742
# [101]	validation_0-rmse:364656.99388
# [102]	validation_0-rmse:364378.63401
# [103]	validation_0-rmse:364468.64906
# [104]	validation_0-rmse:364347.84161
# [105]	validation_0-rmse:364520.59818
# [106]	validation_0-rmse:364470.38948
# [107]	validation_0-rmse:364400.79285
# [108]	validation_0-rmse:364196.50086
# [109]	validation_0-rmse:364405.04306
# [110]	validation_0-rmse:364760.25213
# [111]	validation_0-rmse:364506.46205
# [112]	validation_0-rmse:364559.86978
# [113]	validation_0-rmse:364752.15601
# [114]	validation_0-rmse:364907.93001
# [115]	validation_0-rmse:364974.13214
# [116]	validation_0-rmse:364949.87528
# [117]	validation_0-rmse:365060.51514
# [118]	validation_0-rmse:365098.73026
# [119]	validation_0-rmse:365057.65301
# [120]	validation_0-rmse:364906.12844
# [121]	validation_0-rmse:365211.61246
# [122]	validation_0-rmse:365282.44556
# [123]	validation_0-rmse:365385.49796
# [124]	validation_0-rmse:365402.64535
# [125]	validation_0-rmse:365535.79873
# [126]	validation_0-rmse:366001.69520
# [127]	validation_0-rmse:366181.14425
# [128]	validation_0-rmse:366168.87770
# [129]	validation_0-rmse:366159.43755
# [130]	validation_0-rmse:366008.95148
# [131]	validation_0-rmse:366024.09000
# [132]	validation_0-rmse:365861.01600
# [133]	validation_0-rmse:365728.29658
# [134]	validation_0-rmse:365852.90587
# [135]	validation_0-rmse:365993.28628
# [136]	validation_0-rmse:365973.44371
# [137]	validation_0-rmse:365798.58411
# [138]	validation_0-rmse:366012.02959
# [139]	validation_0-rmse:366034.00969
# [140]	validation_0-rmse:366009.84869
# [141]	validation_0-rmse:366447.75807
# [142]	validation_0-rmse:366519.01540
# [143]	validation_0-rmse:366527.04203
# [144]	validation_0-rmse:366520.83454
# [145]	validation_0-rmse:366561.97424
# [146]	validation_0-rmse:366789.52584
# [147]	validation_0-rmse:367008.71868
# [148]	validation_0-rmse:367002.27967
# [149]	validation_0-rmse:366856.02167
# [150]	validation_0-rmse:367101.45488
# [151]	validation_0-rmse:367145.83493
# [152]	validation_0-rmse:367082.82957
# [153]	validation_0-rmse:367074.80866
# [154]	validation_0-rmse:366996.72787
# [155]	validation_0-rmse:366889.80953
# [156]	validation_0-rmse:367609.65919
# [157]	validation_0-rmse:367584.00542
# [158]	validation_0-rmse:367655.89094
# [159]	validation_0-rmse:367596.60072
# [160]	validation_0-rmse:367594.75089
# [161]	validation_0-rmse:367581.04545
# [162]	validation_0-rmse:367656.68229
# [163]	validation_0-rmse:367505.88939
# [164]	validation_0-rmse:367540.40516
# [165]	validation_0-rmse:367601.00827
# [166]	validation_0-rmse:367649.22851
# [167]	validation_0-rmse:367617.12063
# [168]	validation_0-rmse:367569.98554
# [169]	validation_0-rmse:367536.25516
# [170]	validation_0-rmse:367447.93669
# [171]	validation_0-rmse:367420.31590
# [172]	validation_0-rmse:368282.76127
# [173]	validation_0-rmse:368375.23877
# [174]	validation_0-rmse:368360.61212
# [175]	validation_0-rmse:368403.09380
# [176]	validation_0-rmse:368224.16630
# [177]	validation_0-rmse:368549.90309
# [178]	validation_0-rmse:368557.85390
# [179]	validation_0-rmse:368605.94864
# [180]	validation_0-rmse:368593.42429
# [181]	validation_0-rmse:368951.16514
# [182]	validation_0-rmse:369055.50828
# [183]	validation_0-rmse:369359.29525
# [184]	validation_0-rmse:369502.50524
# [185]	validation_0-rmse:369337.53308
# [186]	validation_0-rmse:369291.00140
# [187]	validation_0-rmse:369277.51700
# [188]	validation_0-rmse:369374.86889
# [189]	validation_0-rmse:370173.59983
# [190]	validation_0-rmse:370328.27397
# [191]	validation_0-rmse:370187.64796
# [192]	validation_0-rmse:370314.03238
# [193]	validation_0-rmse:370348.20489
# [194]	validation_0-rmse:370283.47743
# [195]	validation_0-rmse:370261.82892
# [196]	validation_0-rmse:370297.45730
# [197]	validation_0-rmse:370418.95587
# [198]	validation_0-rmse:370588.39268
# [199]	validation_0-rmse:370742.79966
# [200]	validation_0-rmse:370794.81939
# [201]	validation_0-rmse:370980.37033
# [202]	validation_0-rmse:371047.54157
# [203]	validation_0-rmse:371110.88372
# [204]	validation_0-rmse:371159.69906
# [205]	validation_0-rmse:371137.09715
# [206]	validation_0-rmse:371102.40613
# [207]	validation_0-rmse:371017.42235
# [208]	validation_0-rmse:371022.40846
# [209]	validation_0-rmse:370969.12163
# [210]	validation_0-rmse:371000.09499
# [211]	validation_0-rmse:371090.28619
# [212]	validation_0-rmse:371151.62249
# [213]	validation_0-rmse:371151.11256
# [214]	validation_0-rmse:371242.13541
# [215]	validation_0-rmse:371204.13989
# [216]	validation_0-rmse:371208.38661
# [217]	validation_0-rmse:371154.45226
# [218]	validation_0-rmse:371250.80049
# [219]	validation_0-rmse:371227.62517
# [220]	validation_0-rmse:371156.24999
# [221]	validation_0-rmse:371352.63734
# [222]	validation_0-rmse:371465.47852
# [223]	validation_0-rmse:371457.27369
# [224]	validation_0-rmse:371422.32234
# [225]	validation_0-rmse:371529.76792
# [226]	validation_0-rmse:371784.58652
# [227]	validation_0-rmse:371729.19879
# [228]	validation_0-rmse:371948.97484
# [229]	validation_0-rmse:371928.43783
# [230]	validation_0-rmse:372104.24506
# [231]	validation_0-rmse:372133.54844
# [232]	validation_0-rmse:372121.04339
# [233]	validation_0-rmse:372114.15302
# [234]	validation_0-rmse:371957.91555
# [235]	validation_0-rmse:372077.26105
# [236]	validation_0-rmse:372135.07299
# [237]	validation_0-rmse:372219.28064
# [238]	validation_0-rmse:372216.66499
# [239]	validation_0-rmse:372302.50501
# [240]	validation_0-rmse:372429.69708
# [241]	validation_0-rmse:372540.06463
# [242]	validation_0-rmse:372419.61846
# [243]	validation_0-rmse:372451.75110
# [244]	validation_0-rmse:372485.00529
# [245]	validation_0-rmse:372349.57937
# [246]	validation_0-rmse:372344.22770
# [247]	validation_0-rmse:372369.67737
# [248]	validation_0-rmse:372344.28680
# [249]	validation_0-rmse:372309.59974
# [250]	validation_0-rmse:372385.76186
# [251]	validation_0-rmse:372576.90746
# [252]	validation_0-rmse:372610.64932
# [253]	validation_0-rmse:372612.56196
# [254]	validation_0-rmse:372632.63786
# [255]	validation_0-rmse:372630.41985
# [256]	validation_0-rmse:372712.83579
# [257]	validation_0-rmse:372785.67752
# [258]	validation_0-rmse:372873.00222
# [259]	validation_0-rmse:372918.52600
# [260]	validation_0-rmse:372974.62175
# [261]	validation_0-rmse:372896.47797
# [262]	validation_0-rmse:372893.26762
# [263]	validation_0-rmse:372772.85771
# [264]	validation_0-rmse:372922.16248
# [265]	validation_0-rmse:372936.50250
# [266]	validation_0-rmse:372913.28929
# [267]	validation_0-rmse:372878.63910
# [268]	validation_0-rmse:372894.06679
# [269]	validation_0-rmse:373004.14652
# [270]	validation_0-rmse:373095.79046
# [271]	validation_0-rmse:373202.43268
# [272]	validation_0-rmse:373579.15765
# [273]	validation_0-rmse:373676.40449
# [274]	validation_0-rmse:373654.20233
# [275]	validation_0-rmse:373698.56557
# [276]	validation_0-rmse:373955.92223
# [277]	validation_0-rmse:374099.75013
# [278]	validation_0-rmse:374098.94509
# [279]	validation_0-rmse:374193.46226
# [280]	validation_0-rmse:374313.34574
# [281]	validation_0-rmse:374305.41598
# [282]	validation_0-rmse:374272.96007
# [283]	validation_0-rmse:374261.83768
# [284]	validation_0-rmse:374327.35708
# [285]	validation_0-rmse:374587.79713
# [286]	validation_0-rmse:374566.13506
# [287]	validation_0-rmse:374658.09870
# [288]	validation_0-rmse:374743.39794
# [289]	validation_0-rmse:374644.27791
# [290]	validation_0-rmse:374680.91783
# [291]	validation_0-rmse:374743.87604
# [292]	validation_0-rmse:374791.43139
# [293]	validation_0-rmse:374835.75920
# [294]	validation_0-rmse:374902.94615
# [295]	validation_0-rmse:374915.22906
# [296]	validation_0-rmse:374951.49205
# [297]	validation_0-rmse:374944.51057
# [298]	validation_0-rmse:374902.38866
# [299]	validation_0-rmse:375090.77068
# [300]	validation_0-rmse:375093.08800
# [301]	validation_0-rmse:375026.41547
# [302]	validation_0-rmse:374967.77167
# [303]	validation_0-rmse:375065.22521
# [304]	validation_0-rmse:375041.53729
# [305]	validation_0-rmse:375012.01952
# [306]	validation_0-rmse:375016.38107
# [307]	validation_0-rmse:375352.04249
# [308]	validation_0-rmse:375455.14779
# [309]	validation_0-rmse:375546.41025
# [310]	validation_0-rmse:375660.86677
# [311]	validation_0-rmse:375791.56447
# [312]	validation_0-rmse:375856.05472
# [313]	validation_0-rmse:375848.68057
# [314]	validation_0-rmse:375850.88372
# [315]	validation_0-rmse:375830.91677
# [316]	validation_0-rmse:375898.91587
# [317]	validation_0-rmse:376029.01575
# [318]	validation_0-rmse:376072.15827
# [319]	validation_0-rmse:376155.23304
# [320]	validation_0-rmse:376400.25053
# [321]	validation_0-rmse:376756.90809
# [322]	validation_0-rmse:376703.42342
# [323]	validation_0-rmse:376776.41173
# [324]	validation_0-rmse:376713.99615
# [325]	validation_0-rmse:376892.11548
# [326]	validation_0-rmse:376986.67060
# [327]	validation_0-rmse:377020.46006
# [328]	validation_0-rmse:377181.55086
# [329]	validation_0-rmse:377239.61410
# [330]	validation_0-rmse:377241.03426
# [331]	validation_0-rmse:377298.29573
# [332]	validation_0-rmse:377314.02210
# [333]	validation_0-rmse:377349.95174
# [334]	validation_0-rmse:377363.35717
# [335]	validation_0-rmse:377330.01930
# [336]	validation_0-rmse:377364.78782
# [337]	validation_0-rmse:377349.53445
# [338]	validation_0-rmse:377351.43340
# [339]	validation_0-rmse:377237.99602
# [340]	validation_0-rmse:377281.98030
# [341]	validation_0-rmse:377296.79584
# [342]	validation_0-rmse:377275.10507
# [343]	validation_0-rmse:377268.82857
# [344]	validation_0-rmse:377280.82408
# [345]	validation_0-rmse:377279.96907
# [346]	validation_0-rmse:377315.97891
# [347]	validation_0-rmse:377329.68883
# [348]	validation_0-rmse:377537.85935
# [349]	validation_0-rmse:377555.30288
# [350]	validation_0-rmse:377543.70812
# [351]	validation_0-rmse:377545.70727
# [352]	validation_0-rmse:377538.96864
# [353]	validation_0-rmse:377638.26701
# [354]	validation_0-rmse:377713.90134
# [355]	validation_0-rmse:377724.16335
# [356]	validation_0-rmse:377789.23778
# [357]	validation_0-rmse:377757.47771
# [358]	validation_0-rmse:377912.54337
# [359]	validation_0-rmse:377955.67831
# [360]	validation_0-rmse:378011.90493
# [361]	validation_0-rmse:378124.26297
# [362]	validation_0-rmse:378234.06248
# [363]	validation_0-rmse:378301.53790
# [364]	validation_0-rmse:378288.07768
# [365]	validation_0-rmse:378308.22621
# [366]	validation_0-rmse:378180.16323
# [367]	validation_0-rmse:378219.03017
# [368]	validation_0-rmse:378270.41582
# [369]	validation_0-rmse:378382.45295
# [370]	validation_0-rmse:378423.97097
# [371]	validation_0-rmse:378479.03870
# [372]	validation_0-rmse:378477.45140
# [373]	validation_0-rmse:378492.18306
# [374]	validation_0-rmse:378528.79975
# [375]	validation_0-rmse:378515.21452
# [376]	validation_0-rmse:378534.86218
# [377]	validation_0-rmse:378599.33078
# [378]	validation_0-rmse:378695.12878
# [379]	validation_0-rmse:378708.46028
# [380]	validation_0-rmse:378712.20460
# [381]	validation_0-rmse:378613.42567
# [382]	validation_0-rmse:378624.79656
# [383]	validation_0-rmse:378619.79439
# [384]	validation_0-rmse:378609.49851
# [385]	validation_0-rmse:378611.90147
# [386]	validation_0-rmse:378623.68502
# [387]	validation_0-rmse:378652.13238
# [388]	validation_0-rmse:378682.72495
# [389]	validation_0-rmse:378759.63311
# [390]	validation_0-rmse:378778.57962
# [391]	validation_0-rmse:378825.71886
# [392]	validation_0-rmse:378890.01993
# [393]	validation_0-rmse:378895.39252
# [394]	validation_0-rmse:378880.18168
# [395]	validation_0-rmse:378888.55384
# [396]	validation_0-rmse:378885.39677
# [397]	validation_0-rmse:378961.85052
# [398]	validation_0-rmse:378978.48621
# [399]	validation_0-rmse:378967.15687
# [400]	validation_0-rmse:378931.26306
# [401]	validation_0-rmse:378900.17415
# [402]	validation_0-rmse:378939.25881
# [403]	validation_0-rmse:379032.98441
# [404]	validation_0-rmse:378992.83886
# [405]	validation_0-rmse:378970.05751
# [406]	validation_0-rmse:379053.29464
# [407]	validation_0-rmse:379055.18705
# [408]	validation_0-rmse:379056.27890
# [409]	validation_0-rmse:379082.24312
# [410]	validation_0-rmse:379128.08166
# [411]	validation_0-rmse:379160.44477
# [412]	validation_0-rmse:379145.48940
# [413]	validation_0-rmse:379141.63688
# [414]	validation_0-rmse:379174.35856
# [415]	validation_0-rmse:379212.81890
# [416]	validation_0-rmse:379224.38748
# [417]	validation_0-rmse:379315.48732
# [418]	validation_0-rmse:379329.12577
# [419]	validation_0-rmse:379395.78905
# [420]	validation_0-rmse:379396.50374
# [421]	validation_0-rmse:379502.61503
# [422]	validation_0-rmse:379473.00131
# [423]	validation_0-rmse:379565.79936
# [424]	validation_0-rmse:379560.12170
# [425]	validation_0-rmse:379610.48753
# [426]	validation_0-rmse:379678.11146
# [427]	validation_0-rmse:379708.86726
# [428]	validation_0-rmse:379648.09915
# [429]	validation_0-rmse:379675.55713
# [430]	validation_0-rmse:379746.84810
# [431]	validation_0-rmse:379817.81759
# [432]	validation_0-rmse:379828.38775
# [433]	validation_0-rmse:379798.06186
# [434]	validation_0-rmse:379802.80466
# [435]	validation_0-rmse:379814.20870
# [436]	validation_0-rmse:379954.46791
# [437]	validation_0-rmse:380005.49860
# [438]	validation_0-rmse:379995.18809
# [439]	validation_0-rmse:379997.98475
# [440]	validation_0-rmse:379994.25757
# [441]	validation_0-rmse:380048.26684
# [442]	validation_0-rmse:380055.45310
# [443]	validation_0-rmse:380110.08299
# [444]	validation_0-rmse:380094.12262
# [445]	validation_0-rmse:380133.56636
# [446]	validation_0-rmse:380115.35569
# [447]	validation_0-rmse:380103.28209
# [448]	validation_0-rmse:380060.06078
# [449]	validation_0-rmse:380027.18635
# [450]	validation_0-rmse:380116.11726
# [451]	validation_0-rmse:380106.05687
# [452]	validation_0-rmse:380174.82977
# [453]	validation_0-rmse:380193.35384
# [454]	validation_0-rmse:380247.01245
# [455]	validation_0-rmse:380353.67947
# [456]	validation_0-rmse:380331.41257
# [457]	validation_0-rmse:380319.34692
# [458]	validation_0-rmse:380429.92251
# [459]	validation_0-rmse:380476.73252
# [460]	validation_0-rmse:380545.46038
# [461]	validation_0-rmse:380568.90707
# [462]	validation_0-rmse:380638.40271
# [463]	validation_0-rmse:380638.81114
# [464]	validation_0-rmse:380634.02310
# [465]	validation_0-rmse:380637.83840
# [466]	validation_0-rmse:380596.01031
# [467]	validation_0-rmse:380658.94971
# [468]	validation_0-rmse:380680.87437
# [469]	validation_0-rmse:380709.79541
# [470]	validation_0-rmse:380697.21923
# [471]	validation_0-rmse:380721.61700
# [472]	validation_0-rmse:380732.98267
# [473]	validation_0-rmse:380710.56007
# [474]	validation_0-rmse:380651.10964
# [475]	validation_0-rmse:380664.63324
# [476]	validation_0-rmse:380688.47580
# [477]	validation_0-rmse:380694.01821
# [478]	validation_0-rmse:380816.36907
# [479]	validation_0-rmse:380866.10088
# [480]	validation_0-rmse:380900.58761
# [481]	validation_0-rmse:380899.44157
# [482]	validation_0-rmse:380892.93321
# [483]	validation_0-rmse:380874.42039
# [484]	validation_0-rmse:380944.00944
# [485]	validation_0-rmse:380967.03750
# [486]	validation_0-rmse:380919.68578
# [487]	validation_0-rmse:380978.34651
# [488]	validation_0-rmse:380966.03740
# [489]	validation_0-rmse:380971.64961
# [490]	validation_0-rmse:380995.92447
# [491]	validation_0-rmse:381026.49909
# [492]	validation_0-rmse:381057.43182
# [493]	validation_0-rmse:381106.60667
# [494]	validation_0-rmse:381087.49936
# [495]	validation_0-rmse:381125.58399
# [496]	validation_0-rmse:381141.32249
# [497]	validation_0-rmse:381178.00419
# [498]	validation_0-rmse:381189.87550
# [499]	validation_0-rmse:381191.00794
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### `early_stopping_rounds`
#
# `early_stopping_rounds` ofrece una forma de encontrar automáticamente el valor ideal para `n_estimators`. El early stopping hace que el modelo detenga las iteraciones cuando la puntuación de validación deja de mejorar, incluso si aún no hemos alcanzado el límite establecido por `n_estimators`. Es una buena práctica establecer un valor alto para `n_estimators` y luego usar `early_stopping_rounds` para encontrar el momento óptimo para detener la iteración.
#
# Como el azar puede causar ocasionalmente una sola iteración sin mejora en la puntuación de validación, necesitas especificar cuántas rondas consecutivas de deterioro se permitirán antes de detener el entrenamiento. Establecer `early_stopping_rounds=5` es una elección razonable. En este caso, se detiene después de 5 rondas seguidas de puntuaciones de validación en descenso.
#
# Al usar `early_stopping_rounds`, también necesitas reservar algunos datos para calcular las puntuaciones de validación; esto se hace estableciendo el parámetro `eval_set`.
#
# Podemos modificar el ejemplo anterior para incluir el early stopping:

# %%
# Crear el modelo con 500 estimadores y parada anticipada
my_model = XGBRegressor(n_estimators=500,
                        early_stopping_rounds=5)  # Detener si no hay mejora después de 5 rondas

# Entrenar el modelo utilizando un conjunto de validación para early stopping
my_model.fit(X_train, y_train,
             eval_set=[(X_valid, y_valid)],  # Conjunto de validación para evaluar la mejora
             verbose=True)                  # No mostrar la salida del entrenamiento
# Out:
# [0]	validation_0-rmse:535046.34013
# [1]	validation_0-rmse:477517.68097
# [2]	validation_0-rmse:445198.04336
# [3]	validation_0-rmse:425102.65133
# [4]	validation_0-rmse:411945.25967
# [5]	validation_0-rmse:405890.44880
# [6]	validation_0-rmse:400547.88224
# [7]	validation_0-rmse:396933.52512
# [8]	validation_0-rmse:393692.87844
# [9]	validation_0-rmse:388803.91233
# [10]	validation_0-rmse:385732.60096
# [11]	validation_0-rmse:382896.58555
# [12]	validation_0-rmse:381749.42647
# [13]	validation_0-rmse:379709.58522
# [14]	validation_0-rmse:377954.21082
# [15]	validation_0-rmse:378016.61907
# [16]	validation_0-rmse:376364.60665
# [17]	validation_0-rmse:375963.44145
# [18]	validation_0-rmse:375674.31763
# [19]	validation_0-rmse:375083.77748
# [20]	validation_0-rmse:374593.30015
# [21]	validation_0-rmse:372390.99883
# [22]	validation_0-rmse:371509.05685
# [23]	validation_0-rmse:370833.68153
# [24]	validation_0-rmse:370593.03721
# [25]	validation_0-rmse:370313.79977
# [26]	validation_0-rmse:370002.49249
# [27]	validation_0-rmse:369494.55681
# [28]	validation_0-rmse:369418.01780
# [29]	validation_0-rmse:369004.33866
# [30]	validation_0-rmse:368491.25037
# [31]	validation_0-rmse:368350.26050
# [32]	validation_0-rmse:367956.85953
# [33]	validation_0-rmse:367896.05569
# [34]	validation_0-rmse:367808.59731
# [35]	validation_0-rmse:367949.53590
# [36]	validation_0-rmse:367999.86007
# [37]	validation_0-rmse:367605.51833
# [38]	validation_0-rmse:366919.92409
# [39]	validation_0-rmse:366660.74506
# [40]	validation_0-rmse:366623.98129
# [41]	validation_0-rmse:366279.01616
# [42]	validation_0-rmse:365592.61417
# [43]	validation_0-rmse:365697.50576
# [44]	validation_0-rmse:365447.71242
# [45]	validation_0-rmse:365286.62790
# [46]	validation_0-rmse:365036.44702
# [47]	validation_0-rmse:364895.00256
# [48]	validation_0-rmse:365174.03309
# [49]	validation_0-rmse:364863.82140
# [50]	validation_0-rmse:363829.14820
# [51]	validation_0-rmse:363559.95025
# [52]	validation_0-rmse:363085.10475
# [53]	validation_0-rmse:363014.77678
# [54]	validation_0-rmse:362778.16784
# [55]	validation_0-rmse:362728.72741
# [56]	validation_0-rmse:362699.17441
# [57]	validation_0-rmse:362253.70596
# [58]	validation_0-rmse:362034.57800
# [59]	validation_0-rmse:362159.72000
# [60]	validation_0-rmse:362254.84990
# [61]	validation_0-rmse:362169.85387
# [62]	validation_0-rmse:362182.81120
# [63]	validation_0-rmse:362034.67179
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# Si más adelante deseas ajustar un modelo con todos tus datos, establece `n_estimators` en el valor que encontraste como óptimo al usar parada anticipada (early stopping).
#
# ### `learning_rate`
#
# En lugar de obtener predicciones simplemente sumando las predicciones de cada modelo componente, podemos multiplicar las predicciones de cada modelo por un número pequeño (conocido como **tasa de aprendizaje** o *learning rate*) antes de sumarlas.
#
# Esto significa que cada árbol que añadimos al ensamblado contribuye menos. Por lo tanto, podemos establecer un valor más alto para `n_estimators` sin sobreajustar el modelo. Si usamos parada anticipada, el número apropiado de árboles se determinará automáticamente.
#
# En general, una tasa de aprendizaje pequeña junto con un gran número de estimadores producirá modelos de XGBoost más precisos, aunque también tomará más tiempo entrenarlos, ya que se requieren más iteraciones del ciclo. Por defecto, XGBoost establece `learning_rate=0.1`.
#
# Si Modificamos el ejemplo anterior para cambiar la tasa de aprendizaje produce el siguiente código:

# %%
# Crear el modelo con una tasa de aprendizaje reducida y mayor número de estimadores
my_model = XGBRegressor(n_estimators=5000,          # Incrementamos el numero de estimadores
                        early_stopping_rounds=5,    # Detener si no hay mejora después de 5 rondas
                        learning_rate=0.05)         # Ajustamos la tasa de aprendizaje en 0.05

# Entrenar el modelo con parada anticipada y conjunto de validación
my_model.fit(X_train, y_train,
             eval_set=[(X_valid, y_valid)],  # Evaluar en el conjunto de validación
             verbose=True)                  # No mostrar mensajes durante el entrenamiento
# Out:
# [0]	validation_0-rmse:610600.88216
# [1]	validation_0-rmse:595228.83114
# [2]	validation_0-rmse:581004.97047
# [3]	validation_0-rmse:567803.06131
# [4]	validation_0-rmse:555815.46952
# [5]	validation_0-rmse:544347.64857
# [6]	validation_0-rmse:534024.08015
# [7]	validation_0-rmse:523810.84026
# [8]	validation_0-rmse:514587.57320
# [9]	validation_0-rmse:506305.04891
# [10]	validation_0-rmse:498666.96177
# [11]	validation_0-rmse:490835.83185
# [12]	validation_0-rmse:483846.03508
# [13]	validation_0-rmse:477815.80825
# [14]	validation_0-rmse:471516.73795
# [15]	validation_0-rmse:466075.03817
# [16]	validation_0-rmse:461158.75994
# [17]	validation_0-rmse:456163.01091
# [18]	validation_0-rmse:451610.93800
# [19]	validation_0-rmse:447469.83449
# [20]	validation_0-rmse:443733.87030
# [21]	validation_0-rmse:440450.20707
# [22]	validation_0-rmse:437427.93341
# [23]	validation_0-rmse:434303.66595
# [24]	validation_0-rmse:431591.19825
# [25]	validation_0-rmse:428404.31463
# [26]	validation_0-rmse:425647.45119
# [27]	validation_0-rmse:422785.90823
# [28]	validation_0-rmse:420637.14690
# [29]	validation_0-rmse:418412.34150
# [30]	validation_0-rmse:416448.53637
# [31]	validation_0-rmse:414576.41777
# [32]	validation_0-rmse:412956.87653
# [33]	validation_0-rmse:411016.02267
# [34]	validation_0-rmse:409440.05676
# [35]	validation_0-rmse:408109.67366
# [36]	validation_0-rmse:406866.09043
# [37]	validation_0-rmse:405698.25340
# [38]	validation_0-rmse:404383.14839
# [39]	validation_0-rmse:403188.76626
# [40]	validation_0-rmse:402077.48998
# [41]	validation_0-rmse:401182.20057
# [42]	validation_0-rmse:400372.73111
# [43]	validation_0-rmse:399701.93000
# [44]	validation_0-rmse:398892.78285
# [45]	validation_0-rmse:398090.27204
# [46]	validation_0-rmse:397417.04880
# [47]	validation_0-rmse:396942.36379
# [48]	validation_0-rmse:396228.27518
# [49]	validation_0-rmse:395766.25844
# [50]	validation_0-rmse:395273.29102
# [51]	validation_0-rmse:394908.05017
# [52]	validation_0-rmse:394504.39690
# [53]	validation_0-rmse:394221.35379
# [54]	validation_0-rmse:393728.28513
# [55]	validation_0-rmse:393155.34966
# [56]	validation_0-rmse:392612.96673
# [57]	validation_0-rmse:392386.18489
# [58]	validation_0-rmse:392037.40835
# [59]	validation_0-rmse:391535.58353
# [60]	validation_0-rmse:391393.55795
# [61]	validation_0-rmse:391163.02046
# [62]	validation_0-rmse:390316.00274
# [63]	validation_0-rmse:389603.41814
# [64]	validation_0-rmse:389258.27726
# [65]	validation_0-rmse:388604.88314
# [66]	validation_0-rmse:388351.49703
# [67]	validation_0-rmse:388060.19737
# [68]	validation_0-rmse:387716.45168
# [69]	validation_0-rmse:387372.34589
# [70]	validation_0-rmse:386937.21628
# [71]	validation_0-rmse:386764.31887
# [72]	validation_0-rmse:386540.33758
# [73]	validation_0-rmse:385990.02948
# [74]	validation_0-rmse:385457.61341
# [75]	validation_0-rmse:385175.46527
# [76]	validation_0-rmse:384912.03171
# [77]	validation_0-rmse:384885.06303
# [78]	validation_0-rmse:384476.07734
# [79]	validation_0-rmse:384273.65344
# [80]	validation_0-rmse:383877.43508
# [81]	validation_0-rmse:383403.26996
# [82]	validation_0-rmse:383001.84833
# [83]	validation_0-rmse:382553.78260
# [84]	validation_0-rmse:382211.87750
# [85]	validation_0-rmse:382174.27300
# [86]	validation_0-rmse:382014.00490
# [87]	validation_0-rmse:381672.05217
# [88]	validation_0-rmse:381420.31249
# [89]	validation_0-rmse:381069.02242
# [90]	validation_0-rmse:380722.69271
# [91]	validation_0-rmse:380640.91630
# [92]	validation_0-rmse:380516.35984
# [93]	validation_0-rmse:380440.79177
# [94]	validation_0-rmse:380373.07616
# [95]	validation_0-rmse:380215.91080
# [96]	validation_0-rmse:380098.03387
# [97]	validation_0-rmse:379982.58821
# [98]	validation_0-rmse:379691.93469
# [99]	validation_0-rmse:379584.79596
# [100]	validation_0-rmse:379533.96944
# [101]	validation_0-rmse:379572.44779
# [102]	validation_0-rmse:379251.86238
# [103]	validation_0-rmse:379282.69983
# [104]	validation_0-rmse:379061.29250
# [105]	validation_0-rmse:378901.34571
# [106]	validation_0-rmse:378813.72656
# [107]	validation_0-rmse:378904.34585
# [108]	validation_0-rmse:378656.02000
# [109]	validation_0-rmse:378347.35621
# [110]	validation_0-rmse:378201.81606
# [111]	validation_0-rmse:377956.68262
# [112]	validation_0-rmse:377806.21785
# [113]	validation_0-rmse:377591.10995
# [114]	validation_0-rmse:377536.62987
# [115]	validation_0-rmse:377400.37906
# [116]	validation_0-rmse:377271.13832
# [117]	validation_0-rmse:377207.07270
# [118]	validation_0-rmse:377062.69516
# [119]	validation_0-rmse:376941.47664
# [120]	validation_0-rmse:376871.85214
# [121]	validation_0-rmse:376736.17364
# [122]	validation_0-rmse:376502.12169
# [123]	validation_0-rmse:376437.93615
# [124]	validation_0-rmse:376380.38655
# [125]	validation_0-rmse:376080.08380
# [126]	validation_0-rmse:375988.82883
# [127]	validation_0-rmse:375931.85075
# [128]	validation_0-rmse:375619.39104
# [129]	validation_0-rmse:375596.79906
# [130]	validation_0-rmse:375499.38246
# [131]	validation_0-rmse:375383.68745
# [132]	validation_0-rmse:375316.59236
# [133]	validation_0-rmse:375176.86754
# [134]	validation_0-rmse:374746.83796
# [135]	validation_0-rmse:374701.08487
# [136]	validation_0-rmse:374616.45638
# [137]	validation_0-rmse:374438.66164
# [138]	validation_0-rmse:374260.39957
# [139]	validation_0-rmse:374063.29609
# [140]	validation_0-rmse:374021.70189
# [141]	validation_0-rmse:373823.56423
# [142]	validation_0-rmse:373790.28254
# [143]	validation_0-rmse:373626.32468
# [144]	validation_0-rmse:373415.98870
# [145]	validation_0-rmse:373234.78076
# [146]	validation_0-rmse:373231.48683
# [147]	validation_0-rmse:373168.88680
# [148]	validation_0-rmse:372999.83355
# [149]	validation_0-rmse:372805.53948
# [150]	validation_0-rmse:372713.13900
# [151]	validation_0-rmse:372720.52607
# [152]	validation_0-rmse:372490.59788
# [153]	validation_0-rmse:372442.05763
# [154]	validation_0-rmse:372406.19133
# [155]	validation_0-rmse:372418.94879
# [156]	validation_0-rmse:372233.73275
# [157]	validation_0-rmse:372124.02935
# [158]	validation_0-rmse:372135.63368
# [159]	validation_0-rmse:372043.93442
# [160]	validation_0-rmse:371913.32522
# [161]	validation_0-rmse:371940.58044
# [162]	validation_0-rmse:371834.89196
# [163]	validation_0-rmse:371808.51473
# [164]	validation_0-rmse:371830.80472
# [165]	validation_0-rmse:371687.94326
# [166]	validation_0-rmse:371643.08529
# [167]	validation_0-rmse:371504.89183
# [168]	validation_0-rmse:371440.40088
# [169]	validation_0-rmse:371385.73031
# [170]	validation_0-rmse:371289.92739
# [171]	validation_0-rmse:371031.78645
# [172]	validation_0-rmse:371053.49808
# [173]	validation_0-rmse:370816.72257
# [174]	validation_0-rmse:370742.25764
# [175]	validation_0-rmse:370548.22548
# [176]	validation_0-rmse:370364.56030
# [177]	validation_0-rmse:370236.10249
# [178]	validation_0-rmse:370101.60771
# [179]	validation_0-rmse:370023.87526
# [180]	validation_0-rmse:369982.75738
# [181]	validation_0-rmse:369997.07974
# [182]	validation_0-rmse:369915.38357
# [183]	validation_0-rmse:369950.70953
# [184]	validation_0-rmse:369624.24238
# [185]	validation_0-rmse:369507.69512
# [186]	validation_0-rmse:369414.14915
# [187]	validation_0-rmse:369177.43687
# [188]	validation_0-rmse:369123.27790
# [189]	validation_0-rmse:369077.52169
# [190]	validation_0-rmse:369001.06692
# [191]	validation_0-rmse:368871.30079
# [192]	validation_0-rmse:368587.96123
# [193]	validation_0-rmse:368346.09732
# [194]	validation_0-rmse:368221.56459
# [195]	validation_0-rmse:368136.26053
# [196]	validation_0-rmse:367933.97289
# [197]	validation_0-rmse:367902.94915
# [198]	validation_0-rmse:367924.40614
# [199]	validation_0-rmse:367764.91824
# [200]	validation_0-rmse:367741.58334
# [201]	validation_0-rmse:367717.94847
# [202]	validation_0-rmse:367652.37589
# [203]	validation_0-rmse:367559.16161
# [204]	validation_0-rmse:367370.65815
# [205]	validation_0-rmse:367121.16188
# [206]	validation_0-rmse:367119.94471
# [207]	validation_0-rmse:367059.32682
# [208]	validation_0-rmse:367095.70739
# [209]	validation_0-rmse:367033.61494
# [210]	validation_0-rmse:367024.18851
# [211]	validation_0-rmse:366933.83936
# [212]	validation_0-rmse:366612.00069
# [213]	validation_0-rmse:366631.75933
# [214]	validation_0-rmse:366617.61337
# [215]	validation_0-rmse:366555.73996
# [216]	validation_0-rmse:366545.35496
# [217]	validation_0-rmse:366271.58110
# [218]	validation_0-rmse:366193.61243
# [219]	validation_0-rmse:366174.28818
# [220]	validation_0-rmse:366135.19617
# [221]	validation_0-rmse:366101.46370
# [222]	validation_0-rmse:366012.18589
# [223]	validation_0-rmse:365979.12664
# [224]	validation_0-rmse:365972.52245
# [225]	validation_0-rmse:366041.28336
# [226]	validation_0-rmse:366016.92695
# [227]	validation_0-rmse:365888.85289
# [228]	validation_0-rmse:365831.82741
# [229]	validation_0-rmse:365810.59525
# [230]	validation_0-rmse:365703.46866
# [231]	validation_0-rmse:365680.40096
# [232]	validation_0-rmse:365626.53988
# [233]	validation_0-rmse:365631.82048
# [234]	validation_0-rmse:365599.23839
# [235]	validation_0-rmse:365553.31780
# [236]	validation_0-rmse:365469.16524
# [237]	validation_0-rmse:365343.57684
# [238]	validation_0-rmse:365284.51579
# [239]	validation_0-rmse:365188.54642
# [240]	validation_0-rmse:365135.37687
# [241]	validation_0-rmse:365063.99755
# [242]	validation_0-rmse:364964.26094
# [243]	validation_0-rmse:364812.25231
# [244]	validation_0-rmse:364809.02361
# [245]	validation_0-rmse:364803.45520
# [246]	validation_0-rmse:364615.46904
# [247]	validation_0-rmse:364518.35269
# [248]	validation_0-rmse:364376.37766
# [249]	validation_0-rmse:364307.65106
# [250]	validation_0-rmse:364146.53262
# [251]	validation_0-rmse:364113.53503
# [252]	validation_0-rmse:364096.56960
# [253]	validation_0-rmse:364031.26687
# [254]	validation_0-rmse:363961.24025
# [255]	validation_0-rmse:363903.58985
# [256]	validation_0-rmse:363702.28936
# [257]	validation_0-rmse:363600.18667
# [258]	validation_0-rmse:363549.61037
# [259]	validation_0-rmse:363442.07205
# [260]	validation_0-rmse:363381.74723
# [261]	validation_0-rmse:363334.26127
# [262]	validation_0-rmse:363235.77233
# [263]	validation_0-rmse:363195.20143
# [264]	validation_0-rmse:363031.81985
# [265]	validation_0-rmse:362989.95874
# [266]	validation_0-rmse:362863.99778
# [267]	validation_0-rmse:362744.05197
# [268]	validation_0-rmse:362704.15609
# [269]	validation_0-rmse:362561.16813
# [270]	validation_0-rmse:362532.52398
# [271]	validation_0-rmse:362492.12257
# [272]	validation_0-rmse:362459.82694
# [273]	validation_0-rmse:362400.99506
# [274]	validation_0-rmse:362352.00462
# [275]	validation_0-rmse:362301.88255
# [276]	validation_0-rmse:362113.67942
# [277]	validation_0-rmse:362084.10062
# [278]	validation_0-rmse:362057.98265
# [279]	validation_0-rmse:361902.90801
# [280]	validation_0-rmse:361845.97535
# [281]	validation_0-rmse:361671.68257
# [282]	validation_0-rmse:361635.85795
# [283]	validation_0-rmse:361627.66295
# [284]	validation_0-rmse:361524.56535
# [285]	validation_0-rmse:361516.93763
# [286]	validation_0-rmse:361398.43237
# [287]	validation_0-rmse:361363.46418
# [288]	validation_0-rmse:361329.03955
# [289]	validation_0-rmse:361232.38936
# [290]	validation_0-rmse:361316.04384
# [291]	validation_0-rmse:361182.64149
# [292]	validation_0-rmse:361080.25444
# [293]	validation_0-rmse:361084.64528
# [294]	validation_0-rmse:361062.23819
# [295]	validation_0-rmse:361009.64007
# [296]	validation_0-rmse:360986.73588
# [297]	validation_0-rmse:360975.35294
# [298]	validation_0-rmse:360821.60030
# [299]	validation_0-rmse:360752.01664
# [300]	validation_0-rmse:360691.35590
# [301]	validation_0-rmse:360599.88911
# [302]	validation_0-rmse:360611.23637
# [303]	validation_0-rmse:360590.44337
# [304]	validation_0-rmse:360567.06624
# [305]	validation_0-rmse:360574.29199
# [306]	validation_0-rmse:360535.89733
# [307]	validation_0-rmse:360525.55694
# [308]	validation_0-rmse:360513.25201
# [309]	validation_0-rmse:360485.81351
# [310]	validation_0-rmse:360473.10642
# [311]	validation_0-rmse:360452.85001
# [312]	validation_0-rmse:360382.25325
# [313]	validation_0-rmse:360318.70155
# [314]	validation_0-rmse:360305.29106
# [315]	validation_0-rmse:360256.19846
# [316]	validation_0-rmse:360209.04609
# [317]	validation_0-rmse:360195.91994
# [318]	validation_0-rmse:360209.32921
# [319]	validation_0-rmse:360212.18574
# [320]	validation_0-rmse:360162.50571
# [321]	validation_0-rmse:360075.72713
# [322]	validation_0-rmse:360090.72550
# [323]	validation_0-rmse:360091.54989
# [324]	validation_0-rmse:360076.18209
# [325]	validation_0-rmse:360066.03146
# [326]	validation_0-rmse:360067.75725
# [327]	validation_0-rmse:360046.67282
# [328]	validation_0-rmse:360006.83877
# [329]	validation_0-rmse:359835.52070
# [330]	validation_0-rmse:359712.89674
# [331]	validation_0-rmse:359613.63861
# [332]	validation_0-rmse:359641.18654
# [333]	validation_0-rmse:359583.42924
# [334]	validation_0-rmse:359513.41491
# [335]	validation_0-rmse:359408.14324
# [336]	validation_0-rmse:359324.24370
# [337]	validation_0-rmse:359273.27676
# [338]	validation_0-rmse:359208.95327
# [339]	validation_0-rmse:359168.80969
# [340]	validation_0-rmse:359094.34078
# [341]	validation_0-rmse:359084.61434
# [342]	validation_0-rmse:358987.76589
# [343]	validation_0-rmse:358929.98547
# [344]	validation_0-rmse:358910.91725
# [345]	validation_0-rmse:358884.67255
# [346]	validation_0-rmse:358854.90289
# [347]	validation_0-rmse:358845.55526
# [348]	validation_0-rmse:358850.40555
# [349]	validation_0-rmse:358822.61359
# [350]	validation_0-rmse:358792.87752
# [351]	validation_0-rmse:358765.13056
# [352]	validation_0-rmse:358754.90822
# [353]	validation_0-rmse:358781.71156
# [354]	validation_0-rmse:358756.96347
# [355]	validation_0-rmse:358730.87782
# [356]	validation_0-rmse:358733.71385
# [357]	validation_0-rmse:358714.40246
# [358]	validation_0-rmse:358699.72618
# [359]	validation_0-rmse:358661.03759
# [360]	validation_0-rmse:358653.20164
# [361]	validation_0-rmse:358620.92656
# [362]	validation_0-rmse:358542.70831
# [363]	validation_0-rmse:358590.33614
# [364]	validation_0-rmse:358582.13841
# [365]	validation_0-rmse:358571.98948
# [366]	validation_0-rmse:358579.86213
# [367]	validation_0-rmse:358535.88869
# [368]	validation_0-rmse:358490.06431
# [369]	validation_0-rmse:358491.38834
# [370]	validation_0-rmse:358404.03349
# [371]	validation_0-rmse:358390.19910
# [372]	validation_0-rmse:358395.71748
# [373]	validation_0-rmse:358383.56690
# [374]	validation_0-rmse:358328.28557
# [375]	validation_0-rmse:358302.63687
# [376]	validation_0-rmse:358194.38244
# [377]	validation_0-rmse:358290.73938
# [378]	validation_0-rmse:358244.59768
# [379]	validation_0-rmse:358198.97890
# [380]	validation_0-rmse:358176.41897
# [381]	validation_0-rmse:358107.63564
# [382]	validation_0-rmse:358036.62635
# [383]	validation_0-rmse:358043.82183
# [384]	validation_0-rmse:357998.88576
# [385]	validation_0-rmse:357975.22167
# [386]	validation_0-rmse:357993.19594
# [387]	validation_0-rmse:357948.66775
# [388]	validation_0-rmse:357972.25098
# [389]	validation_0-rmse:357918.44805
# [390]	validation_0-rmse:357845.08496
# [391]	validation_0-rmse:357880.82603
# [392]	validation_0-rmse:357861.54968
# [393]	validation_0-rmse:357845.11732
# [394]	validation_0-rmse:357843.56189
# [395]	validation_0-rmse:357791.16725
# [396]	validation_0-rmse:357716.44142
# [397]	validation_0-rmse:357681.05281
# [398]	validation_0-rmse:357627.06861
# [399]	validation_0-rmse:357609.93706
# [400]	validation_0-rmse:357593.87690
# [401]	validation_0-rmse:357578.74859
# [402]	validation_0-rmse:357733.09148
# [403]	validation_0-rmse:357725.57480
# [404]	validation_0-rmse:357674.60010
# [405]	validation_0-rmse:357673.22577
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=5000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### `n_jobs`
#
# En conjuntos de datos grandes, donde el tiempo de ejecución es una consideración importante, puedes usar paralelismo para construir tus modelos más rápidamente. Es común establecer el parámetro `n_jobs` igual al número de núcleos de tu máquina. En conjuntos de datos pequeños, esto no será de ayuda.
#
# El modelo resultante no será mejor, por lo que microoptimizar el tiempo de ajuste suele ser solo una distracción. Sin embargo, es útil en conjuntos de datos grandes donde de otro modo pasarías mucho tiempo esperando durante la ejecución del comando `fit`.
#
# Aquí tienes el ejemplo modificado:

# %%
# Crear el modelo con paralelismo (4 núcleos), tasa de aprendizaje reducida y early stopping
my_model = XGBRegressor(n_estimators=1000,
                        early_stopping_rounds=5,
                        learning_rate=0.05,
                        n_jobs=4)

# Entrenar el modelo utilizando el conjunto de validación para aplicar early stopping
my_model.fit(X_train, y_train,
             eval_set=[(X_valid, y_valid)],  # Evaluación del rendimiento durante el entrenamiento
             verbose=False)                  # No mostrar salida detallada
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=4,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# # Conclusión
#
# [XGBoost](https://xgboost.readthedocs.io/en/latest/) es una de las bibliotecas de software líderes para trabajar con datos tabulares estándar (el tipo de datos que se almacenan en DataFrames de Pandas, a diferencia de tipos de datos más complejos como imágenes o videos). Con un ajuste cuidadoso de los parámetros, puedes entrenar modelos altamente precisos.
